# %%
import pandas as pd

# %%
df = pd.read_csv('data/data.csv')

# %%
df.columns
# Out:
# Index(['timestamp', 'price_mwh', 'hour', 'day_of_week', 'is_weekend',
#        'is_peak_hours', 'hour_sin', 'hour_cos', 'day_sin', 'day_cos',
#        'price_negative', 'price_high', 'temperature_2m', 'temp_fahrenheit',
#        'relative_humidity_2m', 'wind_speed_10m', 'wind_speed_mph',
#        'wind_direction_10m', 'pressure_msl', 'cloud_cover',
#        'apparent_temperature', 'dew_point_2m', 'temperature_80m',
#        'temperature_120m', 'temperature_180m', 'surface_pressure',
#        'vapour_pressure_deficit', 'wind_speed_80m', 'wind_speed_120m',
#        'wind_speed_180m', 'wind_direction_80m', 'wind_direction_120m',
#        'wind_direction_180m', 'wind_gusts_10m', 'precipitation',
#        'precipitation_probability', 'rain', 'showers', 'snowfall',
#        'snow_depth', 'cloud_cover_low', 'cloud_cover_mid', 'cloud_cover_high',
#        'weather_code', 'visibility', 'evapotranspiration',
#        'et0_fao_evapotranspiration', 'soil_temperature_0cm',
# ...
